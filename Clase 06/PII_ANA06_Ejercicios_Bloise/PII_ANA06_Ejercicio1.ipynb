# %% [markdown]
# #1.Empleando el data set diabetes que se encuentra en el archivo
# #“diabetes.csv”. Se pide realizar el Análisis Exploratorio de Datos.

# %% [markdown]
# .1. Cargar el archivo en un dataframe Pandas.

# %%
#Importo librerias
import pandas as pd

# %%
#Cargo el archivo
df=pd.read_csv("diabetes.csv")

# %% [markdown]
# 1.2. Mostrar el directorio de trabajo donde se encuentra el archivo csv.

# %%
df.to_csv("C:\\Users\\blois\\OneDrive\\Documentos\\Tecnicatura en Cs de Datos e IA\\2do año\\2do Cuatrimestre - 2023\\Programacion II\\Clase 06\\PII_ANA06_Ejercicios_Bloise\\dataset_practico\\diabetes.csv")

# %% [markdown]
# 1.3. Mostrar las dimensiones del dataframw (cuantas filas y columnas tiene)

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# 1.4. Mostrar las columnas que posee el dataframe.

# %%
df.columns
# Out:
# Index(['Embarazos', 'Glucosa', 'Presión Arterial', ' GrosorDePliegueDelaPiel',
#        ' InsulinaSéricaDe2HRS', ' ÍndiceDeMasaCorporal',
#        ' FunciónDePedigríDeDiabetes', ' Edad', 'Clase'],
#       dtype='object')

# %% [markdown]
# 1.5. Mostrar las 10 primeras filas del dataframe.

# %%
df.head(10)
# Out:
#    Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 0          6      148                72                        35
# 1          1       85                66                        29
# 2          8      183                64                         0
# 3          1       89                66                        23
# 4          0      137                40                        35
# 5          5      116                74                         0
# 6          3       78                50                        32
# 7         10      115                 0                         0
# 8          2      197                70                        45
# 9          8      125                96                         0
#
#     InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal   FunciónDePedigríDeDiabetes  \
# 0                      0                   33.6                        0.627
# 1                      0                   26.6                        0.351
# ...

# %% [markdown]
# 1.6. Mostrar cuantos valores únicos hay en la columna “Embarazos”

# %%
df['Embarazos'].nunique()
# Out:
# 17

# %% [markdown]
# 1.7. Mostrar la descripción estadística del dataframe

# %%
df.describe()
# Out:
#         Embarazos     Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# count  768.000000  768.000000        768.000000                768.000000
# mean     3.845052  120.894531         69.105469                 20.536458
# std      3.369578   31.972618         19.355807                 15.952218
# min      0.000000    0.000000          0.000000                  0.000000
# 25%      1.000000   99.000000         62.000000                  0.000000
# 50%      3.000000  117.000000         72.000000                 23.000000
# 75%      6.000000  140.250000         80.000000                 32.000000
# max     17.000000  199.000000        122.000000                 99.000000
#
#         InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal  \
# count             768.000000             768.000000
# mean               79.799479              31.992578
# std               115.244002               7.884160
# min                 0.000000               0.000000
# ...

# %% [markdown]
# 1.8. Mostrar si existen valores nulos en el dataframe (para cada columna)

# %%
df.isnull().sum()
# Out:
# Embarazos                      0
# Glucosa                        0
# Presión Arterial               0
#  GrosorDePliegueDelaPiel       0
#  InsulinaSéricaDe2HRS          0
#  ÍndiceDeMasaCorporal          0
#  FunciónDePedigríDeDiabetes    0
#  Edad                          0
# Clase                          0
# dtype: int64

# %% [markdown]
# 1.9. Mostrar los tipos de datos que posee el dataframe.

# %%
df.dtypes
# Out:
# Embarazos                        int64
# Glucosa                          int64
# Presión Arterial                 int64
#  GrosorDePliegueDelaPiel         int64
#  InsulinaSéricaDe2HRS            int64
#  ÍndiceDeMasaCorporal          float64
#  FunciónDePedigríDeDiabetes    float64
#  Edad                            int64
# Clase                            int64
# dtype: object

# %% [markdown]
# 1.10. Agrupar por la columna “Clase” y calcular la media de cada clase.

# %%
df.groupby('Clase').mean()
# Out:
#        Embarazos     Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# Clase
# 0       3.298000  109.980000         68.184000                 19.664000
# 1       4.865672  141.257463         70.824627                 22.164179
#
#         InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal  \
# Clase
# 0                  68.792000              30.304200
# 1                 100.335821              35.142537
#
#         FunciónDePedigríDeDiabetes       Edad
# Clase
# 0                         0.429734  31.190000
# 1                         0.550500  37.067164

# %% [markdown]
# 1.11. Graficar los datos obtenidos en el punto anterior.

# %%
#Importo libreria para poder graficar
import matplotlib.pyplot as plt

# %%
clase_means = df.groupby('Clase').mean()

# %%
clase_means.plot(kind='bar')
plt.xlabel('Clase')
plt.ylabel('Media')
plt.title('Media de cada columna para cada clase')
plt.show()

# %% [markdown]
# 1.12. Obtener las filas comprendidas entre la 3 y la 6

# %%
df.iloc[3:6]
# Out:
#    Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 3          1       89                66                        23
# 4          0      137                40                        35
# 5          5      116                74                         0
#
#     InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal   FunciónDePedigríDeDiabetes  \
# 3                     94                   28.1                        0.167
# 4                    168                   43.1                        2.288
# 5                      0                   25.6                        0.201
#
#     Edad  Clase
# 3     21      0
# 4     33      1
# 5     30      0

# %% [markdown]
# 1.13. Obtener las filas 0 y 1.

# %%
df.iloc[[0,1]]
# Out:
#    Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 0          6      148                72                        35
# 1          1       85                66                        29
#
#     InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal   FunciónDePedigríDeDiabetes  \
# 0                      0                   33.6                        0.627
# 1                      0                   26.6                        0.351
#
#     Edad  Clase
# 0     50      1
# 1     31      0

# %% [markdown]
# 1.14. Obtener las filas 4 y 5 pero mostrando solo las columnas “Presión Arterial” e “Índice de masa corporal”

# %%
#Imprimo las colunas para ver como estan escritas para el punto de abajo
df.columns
# Out:
# Index(['Embarazos', 'Glucosa', 'Presión Arterial', ' GrosorDePliegueDelaPiel',
#        ' InsulinaSéricaDe2HRS', ' ÍndiceDeMasaCorporal',
#        ' FunciónDePedigríDeDiabetes', ' Edad', 'Clase'],
#       dtype='object')

# %%
df.loc[4:5, ['Presión Arterial', ' ÍndiceDeMasaCorporal']]
# Out:
#    Presión Arterial   ÍndiceDeMasaCorporal
# 4                40                   43.1
# 5                74                   25.6

# %% [markdown]
# 1.15. Mostrar la primer, tercera y quinta fila.

# %%
df.iloc[[0, 2, 4]]
# Out:
#    Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 0          6      148                72                        35
# 2          8      183                64                         0
# 4          0      137                40                        35
#
#     InsulinaSéricaDe2HRS   ÍndiceDeMasaCorporal   FunciónDePedigríDeDiabetes  \
# 0                      0                   33.6                        0.627
# 2                      0                   23.3                        0.672
# 4                    168                   43.1                        2.288
#
#     Edad  Clase
# 0     50      1
# 2     32      1
# 4     33      1

# %% [markdown]
# 1.16. Filtrar a solo las filas cuya edad se igual a 30.

# %%
df_filtrado = df[df[' Edad'] == 30]

# %%
df_filtrado
# Out:
#      Embarazos  Glucosa  Presión Arterial   GrosorDePliegueDelaPiel  \
# 5            5      116                74                         0
# 10           4      110                92                         0
# 52           5       88                66                        21
# 126          3      120                70                        30
# 132          3      170                64                        37
# 256          3      111                56                        39
# 300          0      167                 0                         0
# 309          2      124                68                        28
# 316          3       99                80                        11
# 326          1      122                64                        32
# 351          4      137                84                         0
# 364          4      147                74                        25
# 365          5       99                54                        28
# ...
